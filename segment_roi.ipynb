# %%
import numpy as np
from skimage import morphology
from skimage import measure
from sklearn.cluster import KMeans
from skimage.transform import resize
import matplotlib.pyplot as plt
from glob import glob

working_path = "/disk1/luna16/output/"
image=working_path + "images_0033_0621.npy"
imgs_to_process = np.load(image).astype(np.float64) 
print ("on image", img_file)
# Out:
# on image /disk1/luna16/output/images_0026_1125.npy

# %%
import matplotlib.pyplot as plt
img = imgs_to_process[0]
#Standardize the pixel values
mean = np.mean(img)
std = np.std(img)
img = img-mean
img = img/std
plt.hist(img.flatten(),bins=200)
# Out:
# (array([5.5772e+04, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         4.6300e+02, 1.6050e+03, 3.8910e+03, 8.9780e+03, 1.4192e+04,
#         1.5725e+04, 1.2262e+04, 7.6330e+03, 4.3920e+03, 2.7620e+03,
#         2.0530e+03, 1.5100e+03, 1.2370e+03, 1.0820e+03, 9.3500e+02,
#         8.2900e+02, 6.9500e+02, 6.9600e+02, 5.6300e+02, 4.9200e+02,
#         4.4300e+02, 4.3200e+02, 3.8200e+02, 3.4400e+02, 3.5500e+02,
#         3.3200e+02, 3.9100e+02, 3.5300e+02, 3.5800e+02, 3.3500e+02,
#         3.3500e+02, 3.3400e+02, 3.5300e+02, 3.5800e+02, 3.9600e+02,
#         4.4100e+02, 5.0100e+02, 6.1000e+02, 9.8500e+02, 2.3500e+03,
#         6.9960e+03, 1.3341e+04, 1.3756e+04, 9.1120e+03, 6.4160e+03,
#         6.1670e+03, 7.1420e+03, 9.0580e+03, 1.0700e+04, 1.0832e+04,
#         7.4260e+03, 3.4780e+03, 1.5530e+03, 9.7000e+02, 7.1800e+02,
#         6.2100e+02, 5.2400e+02, 5.5000e+02, 4.6800e+02, 3.3500e+02,
#         3.1900e+02, 3.0800e+02, 2.5700e+02, 2.3100e+02, 2.2600e+02,
#         1.9200e+02, 1.6200e+02, 1.6200e+02, 1.3500e+02, 9.9000e+01,
#         1.3100e+02, 1.0800e+02, 1.1300e+02, 1.0100e+02, 8.2000e+01,
#         8.2000e+01, 7.9000e+01, 8.0000e+01, 7.7000e+01, 8.7000e+01,
#         7.8000e+01, 5.8000e+01, 6.4000e+01, 6.0000e+01, 6.6000e+01,
#         4.8000e+01, 5.0000e+01, 4.4000e+01, 4.4000e+01, 2.7000e+01,
#         2.9000e+01, 3.5000e+01, 3.2000e+01, 2.9000e+01, 2.5000e+01,
#         3.0000e+01, 1.9000e+01, 2.0000e+01, 9.0000e+00, 9.0000e+00,
#         5.0000e+00, 4.0000e+00, 2.0000e+00, 2.0000e+00, 3.0000e+00,
#         0.0000e+00, 1.0000e+00, 1.0000e+00, 0.0000e+00, 1.0000e+00]),
#  array([-1.80789528, -1.78877742, -1.76965957, -1.75054172, -1.73142386,
#         -1.71230601, -1.69318816, -1.6740703 , -1.65495245, -1.63583459,
#         -1.61671674, -1.59759889, -1.57848103, -1.55936318, -1.54024533,
#         -1.52112747, -1.50200962, -1.48289176, -1.46377391, -1.44465606,
#         -1.4255382 , -1.40642035, -1.3873025 , -1.36818464, -1.34906679,
#         -1.32994893, -1.31083108, -1.29171323, -1.27259537, -1.25347752,
#         -1.23435967, -1.21524181, -1.19612396, -1.1770061 , -1.15788825,
#         -1.1387704 , -1.11965254, -1.10053469, -1.08141683, -1.06229898,
#         -1.04318113, -1.02406327, -1.00494542, -0.98582757, -0.96670971,
#         -0.94759186, -0.928474  , -0.90935615, -0.8902383 , -0.87112044,
#         -0.85200259, -0.83288474, -0.81376688, -0.79464903, -0.77553117,
#         -0.75641332, -0.73729547, -0.71817761, -0.69905976, -0.67994191,
#         -0.66082405, -0.6417062 , -0.62258834, -0.60347049, -0.58435264,
#         -0.56523478, -0.54611693, -0.52699908, -0.50788122, -0.48876337,
#         -0.46964551, -0.45052766, -0.43140981, -0.41229195, -0.3931741 ,
#         -0.37405624, -0.35493839, -0.33582054, -0.31670268, -0.29758483,
#         -0.27846698, -0.25934912, -0.24023127, -0.22111341, -0.20199556,
#         -0.18287771, -0.16375985, -0.144642  , -0.12552415, -0.10640629,
#         -0.08728844, -0.06817058, -0.04905273, -0.02993488, -0.01081702,
#          0.00830083,  0.02741868,  0.04653654,  0.06565439,  0.08477225,
#          0.1038901 ,  0.12300795,  0.14212581,  0.16124366,  0.18036151,
#          0.19947937,  0.21859722,  0.23771508,  0.25683293,  0.27595078,
#          0.29506864,  0.31418649,  0.33330435,  0.3524222 ,  0.37154005,
#          0.39065791,  0.40977576,  0.42889361,  0.44801147,  0.46712932,
#          0.48624718,  0.50536503,  0.52448288,  0.54360074,  0.56271859,
#          0.58183644,  0.6009543 ,  0.62007215,  0.63919001,  0.65830786,
#          0.67742571,  0.69654357,  0.71566142,  0.73477927,  0.75389713,
#          0.77301498,  0.79213284,  0.81125069,  0.83036854,  0.8494864 ,
#          0.86860425,  0.8877221 ,  0.90683996,  0.92595781,  0.94507567,
#          0.96419352,  0.98331137,  1.00242923,  1.02154708,  1.04066494,
#          1.05978279,  1.07890064,  1.0980185 ,  1.11713635,  1.1362542 ,
#          1.15537206,  1.17448991,  1.19360777,  1.21272562,  1.23184347,
#          1.25096133,  1.27007918,  1.28919703,  1.30831489,  1.32743274,
#          1.3465506 ,  1.36566845,  1.3847863 ,  1.40390416,  1.42302201,
#          1.44213986,  1.46125772,  1.48037557,  1.49949343,  1.51861128,
#          1.53772913,  1.55684699,  1.57596484,  1.59508269,  1.61420055,
#          1.6333184 ,  1.65243626,  1.67155411,  1.69067196,  1.70978982,
#          1.72890767,  1.74802552,  1.76714338,  1.78626123,  1.80537909,
#          1.82449694,  1.84361479,  1.86273265,  1.8818505 ,  1.90096836,
#          1.92008621,  1.93920406,  1.95832192,  1.97743977,  1.99655762,
#          2.01567548]),
#  <a list of 200 Patch objects>)

# %% [markdown]
# We have to make sure that we set our threshold between the lung pixel values and the denser tissue pixel values.

# %%
middle = img[100:400,100:400] 
mean = np.mean(middle)  
max = np.max(img)
min = np.min(img)
#move the underflow bins
img[img==max]=mean
img[img==min]=mean

kmeans = KMeans(n_clusters=2).fit(np.reshape(middle,[np.prod(middle.shape),1]))
centers = sorted(kmeans.cluster_centers_.flatten())
threshold = np.mean(centers)
thresh_img = np.where(img<threshold,1.0,0.0)  # threshold the image

plt.imshow(thresh_img,cmap='gray')

# %% [markdown]
# # apply erosion and dilation

# %%
eroded = morphology.erosion(thresh_img,np.ones([4,4]))
dilation = morphology.dilation(eroded,np.ones([10,10]))
labels = measure.label(dilation)
label_vals = np.unique(labels)
plt.imshow(labels)

# %% [markdown]
# ## lungs are generally far away from the top and bottom of the image, so any regions that are too close to the top and bottom are removed

# %%
labels = measure.label(dilation)
label_vals = np.unique(labels)
regions = measure.regionprops(labels)
good_labels = []
for prop in regions:
    B = prop.bbox
    if B[2]-B[0]<475 and B[3]-B[1]<475 and B[0]>40 and B[2]<472:
        good_labels.append(prop.label)
mask = np.ndarray([512,512],dtype=np.int8)
mask[:] = 0
#
#  The mask here is the mask for the lungs--not the nodes
#  After just the lungs are left, we do another large dilation
#  in order to fill in and out the lung mask 
#
for N in good_labels:
    mask = mask + np.where(labels==N,1,0)
mask = morphology.dilation(mask,np.ones([10,10])) # one last dilation
plt.imshow(mask,cmap='gray')

# %% [markdown]
# # Applying the masks and cropping and resizing the image
# applying the mask of the lung ROI to each of the images, cropping down to the bounding square of the lungs ROI, and then resizing the resulting image to 512 X 512.

# %%
sample_mask = working_path+"lungmask_0033_0621.npy"
sample_img = working_path+"images_0033_0621.npy"
masks = np.load(sample_mask)
imgs = np.load(sample_img)
imgs = masks*imgs

# %% [markdown]
# ## renormalizing the masked image (in the mask region)

# %%
new_mean = np.mean(img[mask>0])  
new_std = np.std(img[mask>0])
#
#  Pushing the background color up to the lower end
#  of the pixel range for the lungs
#
old_min = np.min(img)       # background color
img[img==old_min] = new_mean-1.2*new_std   # resetting backgound color
img = img-new_mean
img = img/new_std
plt.imshow(img,cmap='gray')

# %% [markdown]
# ## Writing out images and masks as 1 channel to feed into unet

# %%
#
#  Writing out images and masks as 1 channel arrays for input into network
#
final_images = np.ndarray([num_images,1,512,512],dtype=np.float32)
final_masks = np.ndarray([num_images,1,512,512],dtype=np.float32)
for i in range(num_images):
    final_images[i,0] = out_images[i]
    final_masks[i,0] = out_nodemasks[i]

rand_i = np.random.choice(range(num_images),size=num_images,replace=False)
test_i = int(0.2*num_images)
np.save(working_path+"trainImages.npy",final_images[rand_i[test_i:]])
np.save(working_path+"trainMasks.npy",final_masks[rand_i[test_i:]])
np.save(working_path+"testImages.npy",final_images[rand_i[:test_i]])
np.save(working_path+"testMasks.npy",final_masks[rand_i[:test_i]])

# %% [markdown]
# # check roi isolating

# %%
imgs = np.load(sample_img)
lungmask = np.load(sample_mask)

for i in range(len(imgs)):
    print ("image %d" % i)
    fig,ax = plt.subplots(2,2,figsize=[8,8])
    ax[0,0].imshow(imgs[i],cmap='gray')
    ax[0,1].imshow(lungmask[i],cmap='gray')
    ax[1,0].imshow(imgs[i]*lungmask[i],cmap='gray')
    plt.show()
# Out:
# image 0
# image 1
# image 2

# %% [markdown]
# # Run all images

# %%
import numpy as np
from skimage import morphology
from skimage import measure
from sklearn.cluster import KMeans
from skimage.transform import resize
import matplotlib.pyplot as plt
from glob import glob

working_path = "/disk1/luna16/output/"
file_list=glob(working_path+"images_*.npy")

for img_file in file_list:
    # I ran into an error when using Kmean on np.float16, so I'm using np.float64 here
    imgs_to_process = np.load(img_file).astype(np.float64) 
    print ("on image", img_file)
    for i in range(len(imgs_to_process)):
        img = imgs_to_process[i]
        #Standardize the pixel values
        mean = np.mean(img)
        std = np.std(img)
        img = img-mean
        img = img/std
        # Find the average pixel value near the lungs
        # to renormalize washed out images
        middle = img[100:400,100:400] 
        mean = np.mean(middle)  
        max = np.max(img)
        min = np.min(img)
        # To improve threshold finding, I'm moving the 
        # underflow and overflow on the pixel spectrum
        img[img==max]=mean
        img[img==min]=mean
        #
        # Using Kmeans to separate foreground (radio-opaque tissue)
        # and background (radio transparent tissue ie lungs)
        # Doing this only on the center of the image to avoid 
        # the non-tissue parts of the image as much as possible
        #
        kmeans = KMeans(n_clusters=2).fit(np.reshape(middle,[np.prod(middle.shape),1]))
        centers = sorted(kmeans.cluster_centers_.flatten())
        threshold = np.mean(centers)
        thresh_img = np.where(img<threshold,1.0,0.0)  # threshold the image
        #
        # I found an initial erosion helful for removing graininess from some of the regions
        # and then large dialation is used to make the lung region 
        # engulf the vessels and incursions into the lung cavity by 
        # radio opaque tissue
        #
        eroded = morphology.erosion(thresh_img,np.ones([4,4]))
        dilation = morphology.dilation(eroded,np.ones([10,10]))
        #
        #  Label each region and obtain the region properties
        #  The background region is removed by removing regions 
        #  with a bbox that is to large in either dimnsion

        #  This does not produce a perfect segmentation of the lungs
        #  from the image, but it is surprisingly good considering its
        #  simplicity. 
        #
        labels = measure.label(dilation)
        label_vals = np.unique(labels)
        regions = measure.regionprops(labels)
        good_labels = []
        for prop in regions:
            B = prop.bbox
            if B[2]-B[0]<475 and B[3]-B[1]<475 and B[0]>40 and B[2]<472:
                good_labels.append(prop.label)
        mask = np.ndarray([512,512],dtype=np.int8)
        mask[:] = 0
        #
        #  The mask here is the mask for the lungs--not the nodes
        #  After just the lungs are left, we do another large dilation
        #  in order to fill in and out the lung mask 
        #
        for N in good_labels:
            mask = mask + np.where(labels==N,1,0)
        mask = morphology.dilation(mask,np.ones([10,10])) # one last dilation
        imgs_to_process[i] = mask
        print (imgs_to_process)
        
    np.save(img_file.replace("images","lungmask"), imgs_to_process)

# %%
file_list=glob(working_path+"lungmask_*.npy")
out_images = []      #final set of images
out_nodemasks = []   #final set of nodemasks
for fname in file_list:
    print ("working on file ", fname)
    imgs_to_process = np.load(fname.replace("lungmask","images"))
    masks = np.load(fname)
    node_masks = np.load(fname.replace("lungmask","masks"))
    for i in range(len(imgs_to_process)):
        mask = masks[i]
        node_mask = node_masks[i]
        img = imgs_to_process[i]
        new_size = [512,512]   # we're scaling back up to the original size of the image
        img= mask*img          # apply lung mask
        #
        # renormalizing the masked image (in the mask region)
        #
        new_mean = np.mean(img[mask>0])  
        new_std = np.std(img[mask>0])
        #
        #  Pulling the background color up to the lower end
        #  of the pixel range for the lungs
        #
        old_min = np.min(img)       # background color
        img[img==old_min] = new_mean-1.2*new_std   # resetting backgound color
        img = img-new_mean
        img = img/new_std
        #make image bounding box  (min row, min col, max row, max col)
        labels = measure.label(mask)
        regions = measure.regionprops(labels)
        #
        # Finding the global min and max row over all regions
        #
        min_row = 512
        max_row = 0
        min_col = 512
        max_col = 0
        for prop in regions:
            B = prop.bbox
            if min_row > B[0]:
                min_row = B[0]
            if min_col > B[1]:
                min_col = B[1]
            if max_row < B[2]:
                max_row = B[2]
            if max_col < B[3]:
                max_col = B[3]
                
        width = max_col-min_col
        height = max_row - min_row
        if width > height:
            max_row=min_row+width
        else:
            max_col = min_col+height
        # 
        # cropping the image down to the bounding box for all regions
        # (there's probably an skimage command that can do this in one line)
        # 
        img = img[min_row:max_row,min_col:max_col]
        mask =  mask[min_row:max_row,min_col:max_col]
        if max_row-min_row <5 or max_col-min_col<5:  # skipping all images with no god regions
            pass
        else:
            # moving range to -1 to 1 to accomodate the resize function
            mean = np.mean(img)
            img = img - mean
            min = np.min(img)
            max = np.max(img)
            img = img/(max-min)
            new_img = resize(img,[512,512])
            new_node_mask = resize(node_mask[min_row:max_row,min_col:max_col],[512,512])
            out_images.append(new_img)
            out_nodemasks.append(new_node_mask)

num_images = len(out_images)
#
#  Writing out images and masks as 1 channel arrays for input into network
#
final_images = np.ndarray([num_images,1,512,512],dtype=np.float32)
final_masks = np.ndarray([num_images,1,512,512],dtype=np.float32)
for i in range(num_images):
    final_images[i,0] = out_images[i]
    final_masks[i,0] = out_nodemasks[i]

rand_i = np.random.choice(range(num_images),size=num_images,replace=False)
test_i = int(0.2*num_images)
print (test_i)
np.save(working_path+"trainImages.npy",final_images[rand_i[test_i:]])
np.save(working_path+"trainMasks.npy",final_masks[rand_i[test_i:]])
np.save(working_path+"testImages.npy",final_images[rand_i[:test_i]])
np.save(working_path+"testMasks.npy",final_masks[rand_i[:test_i]])
# Out:
# working on file  /disk1/luna16/output/lungmask_0080_0798.npy
# /opt/conda/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# working on file  /disk1/luna16/output/lungmask_0024_0937.npy
# working on file  /disk1/luna16/output/lungmask_0084_0491.npy
# working on file  /disk1/luna16/output/lungmask_0020_1012.npy
# working on file  /disk1/luna16/output/lungmask_0010_0839.npy
# working on file  /disk1/luna16/output/lungmask_0019_0026.npy
# working on file  /disk1/luna16/output/lungmask_0049_0367.npy
# working on file  /disk1/luna16/output/lungmask_0002_1117.npy
# working on file  /disk1/luna16/output/lungmask_0062_1137.npy
# working on file  /disk1/luna16/output/lungmask_0002_1116.npy
# working on file  /disk1/luna16/output/lungmask_0081_0898.npy
# working on file  /disk1/luna16/output/lungmask_0071_0345.npy
# working on file  /disk1/luna16/output/lungmask_0020_1013.npy
# working on file  /disk1/luna16/output/lungmask_0031_0130.npy
# working on file  /disk1/luna16/output/lungmask_0032_0135.npy
# working on file  /disk1/luna16/output/lungmask_0009_0149.npy
# working on file  /disk1/luna16/output/lungmask_0031_0129.npy
# working on file  /disk1/luna16/output/lungmask_0064_0793.npy
# working on file  /disk1/luna16/output/lungmask_0066_0987.npy
# working on file  /disk1/luna16/output/lungmask_0062_1138.npy
# working on file  /disk1/luna16/output/lungmask_0038_1022.npy
# working on file  /disk1/luna16/output/lungmask_0082_0117.npy
# working on file  /disk1/luna16/output/lungmask_0045_0023.npy
# working on file  /disk1/luna16/output/lungmask_0024_0939.npy
# working on file  /disk1/luna16/output/lungmask_0023_1109.npy
# working on file  /disk1/luna16/output/lungmask_0018_0871.npy
# working on file  /disk1/luna16/output/lungmask_0024_0938.npy
# working on file  /disk1/luna16/output/lungmask_0011_0456.npy
# working on file  /disk1/luna16/output/lungmask_0007_0630.npy
# working on file  /disk1/luna16/output/lungmask_0033_0622.npy
# working on file  /disk1/luna16/output/lungmask_0020_1011.npy
# working on file  /disk1/luna16/output/lungmask_0013_0978.npy
# working on file  /disk1/luna16/output/lungmask_0026_1123.npy
# working on file  /disk1/luna16/output/lungmask_0046_0507.npy
# working on file  /disk1/luna16/output/lungmask_0048_0873.npy
# working on file  /disk1/luna16/output/lungmask_0019_0025.npy
# working on file  /disk1/luna16/output/lungmask_0039_1073.npy
# working on file  /disk1/luna16/output/lungmask_0033_0620.npy
# working on file  /disk1/luna16/output/lungmask_0017_0420.npy
# working on file  /disk1/luna16/output/lungmask_0033_0621.npy
# working on file  /disk1/luna16/output/lungmask_0003_0086.npy
# working on file  /disk1/luna16/output/lungmask_0029_0836.npy
# working on file  /disk1/luna16/output/lungmask_0013_0980.npy
# working on file  /disk1/luna16/output/lungmask_0026_1125.npy
# working on file  /disk1/luna16/output/lungmask_0083_0791.npy
# working on file  /disk1/luna16/output/lungmask_0054_0347.npy
# working on file  /disk1/luna16/output/lungmask_0040_0783.npy
# working on file  /disk1/luna16/output/lungmask_0079_1016.npy
# working on file  /disk1/luna16/output/lungmask_0064_0792.npy
# working on file  /disk1/luna16/output/lungmask_0058_0748.npy
# working on file  /disk1/luna16/output/lungmask_0054_0349.npy
# working on file  /disk1/luna16/output/lungmask_0001_0144.npy
# working on file  /disk1/luna16/output/lungmask_0054_0350.npy
# working on file  /disk1/luna16/output/lungmask_0067_1054.npy
# working on file  /disk1/luna16/output/lungmask_0066_0988.npy
# working on file  /disk1/luna16/output/lungmask_0081_0897.npy
# working on file  /disk1/luna16/output/lungmask_0083_0789.npy
# working on file  /disk1/luna16/output/lungmask_0073_1018.npy
# working on file  /disk1/luna16/output/lungmask_0028_0477.npy
# working on file  /disk1/luna16/output/lungmask_0074_0098.npy
# working on file  /disk1/luna16/output/lungmask_0072_0199.npy
# working on file  /disk1/luna16/output/lungmask_0038_1021.npy
# working on file  /disk1/luna16/output/lungmask_0039_1074.npy
# working on file  /disk1/luna16/output/lungmask_0084_0490.npy
# working on file  /disk1/luna16/output/lungmask_0061_0335.npy
# working on file  /disk1/luna16/output/lungmask_0052_1106.npy
# working on file  /disk1/luna16/output/lungmask_0032_0136.npy
# working on file  /disk1/luna16/output/lungmask_0031_0132.npy
# working on file  /disk1/luna16/output/lungmask_0080_0796.npy
# working on file  /disk1/luna16/output/lungmask_0056_0976.npy
# working on file  /disk1/luna16/output/lungmask_0030_0705.npy
# working on file  /disk1/luna16/output/lungmask_0031_0131.npy
# working on file  /disk1/luna16/output/lungmask_0054_0348.npy
# working on file  /disk1/luna16/output/lungmask_0073_1019.npy
# working on file  /disk1/luna16/output/lungmask_0013_0979.npy
# working on file  /disk1/luna16/output/lungmask_0050_1141.npy
# working on file  /disk1/luna16/output/lungmask_0053_0872.npy
# working on file  /disk1/luna16/output/lungmask_0080_0797.npy
# working on file  /disk1/luna16/output/lungmask_0040_0784.npy
# working on file  /disk1/luna16/output/lungmask_0085_0103.npy
# working on file  /disk1/luna16/output/lungmask_0077_0882.npy
# working on file  /disk1/luna16/output/lungmask_0011_0454.npy
# working on file  /disk1/luna16/output/lungmask_0060_0536.npy
# working on file  /disk1/luna16/output/lungmask_0035_0732.npy
# working on file  /disk1/luna16/output/lungmask_0080_0795.npy
# working on file  /disk1/luna16/output/lungmask_0008_0110.npy
# working on file  /disk1/luna16/output/lungmask_0005_1084.npy
# working on file  /disk1/luna16/output/lungmask_0046_0506.npy
# working on file  /disk1/luna16/output/lungmask_0057_1072.npy
# working on file  /disk1/luna16/output/lungmask_0027_0580.npy
# working on file  /disk1/luna16/output/lungmask_0073_1017.npy
# working on file  /disk1/luna16/output/lungmask_0035_0733.npy
# working on file  /disk1/luna16/output/lungmask_0042_0139.npy
# working on file  /disk1/luna16/output/lungmask_0022_0889.npy
# working on file  /disk1/luna16/output/lungmask_0080_0794.npy
# working on file  /disk1/luna16/output/lungmask_0000_0858.npy
# working on file  /disk1/luna16/output/lungmask_0086_1030.npy
# working on file  /disk1/luna16/output/lungmask_0083_0790.npy
# working on file  /disk1/luna16/output/lungmask_0075_0935.npy
# working on file  /disk1/luna16/output/lungmask_0023_1108.npy
# working on file  /disk1/luna16/output/lungmask_0010_0838.npy
# working on file  /disk1/luna16/output/lungmask_0038_1020.npy
# working on file  /disk1/luna16/output/lungmask_0034_1049.npy
# working on file  /disk1/luna16/output/lungmask_0078_0970.npy
# working on file  /disk1/luna16/output/lungmask_0076_1180.npy
# working on file  /disk1/luna16/output/lungmask_0028_0478.npy
# working on file  /disk1/luna16/output/lungmask_0071_0344.npy
# working on file  /disk1/luna16/output/lungmask_0055_0966.npy
# working on file  /disk1/luna16/output/lungmask_0026_1124.npy
# working on file  /disk1/luna16/output/lungmask_0061_0336.npy
# working on file  /disk1/luna16/output/lungmask_0011_0455.npy
# working on file  /disk1/luna16/output/lungmask_0088_0028.npy
